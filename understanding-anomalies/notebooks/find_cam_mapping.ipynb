# %%
import pandas as pd
import numpy as np
from brpylib import NevFile, NsxFile
import json
from pyvideosync.nev import Nev
from pyvideosync.nsx import Nsx
from pyvideosync.match import Match
from pyvideosync.videojson import Videojson
from pyvideosync import utils
import soundfile as sf
import matplotlib.pyplot as plt
import os
from datetime import datetime
from collections import Counter
import cv2
from tqdm import tqdm

# %%
# !pwd
# Out:
# /home/yewen/BCM/videosync/05242024

# %%
paths = {
    "B1": "nsp/grounded_pins_B1_only/20240524-162117/NSP1-20240524-162117-001.nev",
    "B2": "nsp/grounded_pins_B2_only/20240524-162427/NSP1-20240524-162427-001.nev",
    "F1": "nsp/grounded_pins_F1_only/20240524-160708/NSP1-20240524-160708-001.nev",
    "F2": "nsp/grounded_pins_F2_only/20240524-160911/NSP1-20240524-160911-001.nev",
    "F3": "nsp/grounded_pins_F3_only/20240524-161902/NSP1-20240524-161902-001.nev",
    "R1": "nsp/grounded_pins_R1_only/20240524-162641/NSP1-20240524-162641-001.nev",
    "R2": "nsp/grounded_pins_R2_only/20240524-163000/NSP1-20240524-163000-001.nev",
    "R3": "nsp/grounded_pins_R3_only/20240524-163219/NSP1-20240524-163219-001.nev",
}

# %%
# dir to save plots
plot_dir = "plot/"

# %%
for cam, path in paths.items():
    nev = Nev(path)
    print(f"Cam: {cam}")
    save_name = f"Cam_{cam}.png"
    nev.plot_cam_exposure_all(plot_dir, 200, save_name)
# Out:
# NSP1-20240524-162117-001.nev opened
#
# NSP1-20240524-162117-001.nev closed
# Cam: B1
# NSP1-20240524-162427-001.nev opened
#
# NSP1-20240524-162427-001.nev closed
# Cam: B2
# NSP1-20240524-160708-001.nev opened
#
# NSP1-20240524-160708-001.nev closed
# Cam: F1
# NSP1-20240524-160911-001.nev opened
#
# NSP1-20240524-160911-001.nev closed
# Cam: F2
# NSP1-20240524-161902-001.nev opened
#
# NSP1-20240524-161902-001.nev closed
# Cam: F3
# NSP1-20240524-162641-001.nev opened
#
# NSP1-20240524-162641-001.nev closed
# Cam: R1
# NSP1-20240524-163000-001.nev opened
#
# NSP1-20240524-163000-001.nev closed
# Cam: R2
# NSP1-20240524-163219-001.nev opened
#
# NSP1-20240524-163219-001.nev closed
# Cam: R3
